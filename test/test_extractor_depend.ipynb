# %%
import unittest
import extractor_depend

class Testextract(unittest.TestCase):
    def test_extractor(self):
        input_file = '../xkcd2347/data_collection/Input_data/3k_valid_repos'
        output_file = '3krepodata_test'
        git_hub_key = 'github_token'
        hop = 1
        extractor_depend.getDependencies(input_file, output_file, git_hub_key, hop)

if __name__ == "__main__":
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
#   0%|                                                                                 | 1/1440 [00:01<47:52,  2.00s/it]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "pymedphys", name: "pymedphys") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 pymedphys/pymedphys
#   0%|                                                                                 | 2/1440 [00:02<36:39,  1.53s/it]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "anuprulez", name: "galaxy_tool_recommendation") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 anuprulez/galaxy_tool_recommendation
#   0%|▏                                                                                | 3/1440 [00:02<28:50,  1.20s/it]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "BMKEG", name: "sciDT-pipeline") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 BMKEG/sciDT-pipeline
#   0%|▏                                                                                | 4/1440 [00:03<23:26,  1.02it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "Irstea", name: "otolithe") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 Irstea/otolithe
#   0%|▎                                                                                | 5/1440 [00:03<19:34,  1.22it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "hugovk", name: "pypistats") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 hugovk/pypistats
#   0%|▎                                                                                | 6/1440 [00:04<17:03,  1.40it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "single-cell-genetics", name: "vireo") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 single-cell-genetics/vireo
#   0%|▍                                                                                | 7/1440 [00:04<15:09,  1.58it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "bionode", name: "bionode") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 bionode/bionode
#   1%|▍                                                                                | 8/1440 [00:05<13:39,  1.75it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "Edric-Matwiejew", name: "QuOp_MPI") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 Edric-Matwiejew/QuOp_MPI
#   1%|▌                                                                                | 9/1440 [00:05<12:44,  1.87it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "evanodell", name: "parlitools") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 evanodell/parlitools
#   1%|▌                                                                               | 10/1440 [00:05<11:55,  2.00it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "steven-murray", name: "hankel") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 steven-murray/hankel
#   1%|▌                                                                               | 11/1440 [00:06<11:45,  2.02it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "guillochon", name: "MOSFiT") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 guillochon/MOSFiT
#   1%|▋                                                                               | 12/1440 [00:06<11:39,  2.04it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "lascivaroma", name: "priapeia") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 lascivaroma/priapeia
#   1%|▋                                                                               | 13/1440 [00:07<11:29,  2.07it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "vahtras", name: "loprop") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 vahtras/loprop
#   1%|▊                                                                               | 14/1440 [00:07<11:17,  2.11it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "pv8", name: "noipy") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 pv8/noipy
#   1%|▊                                                                               | 15/1440 [00:08<11:04,  2.14it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "MAfarrag", name: "Hapi") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 MAfarrag/Hapi
#   1%|▉                                                                               | 16/1440 [00:08<11:07,  2.13it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "monteirotorres", name: "ProtCHOIR") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 monteirotorres/ProtCHOIR
#   1%|▉                                                                               | 17/1440 [00:09<11:01,  2.15it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "dejac001", name: "adsorption_isotherm_fitting") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 dejac001/adsorption_isotherm_fitting
#   1%|█                                                                               | 18/1440 [00:09<11:00,  2.15it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "GilesStrong", name: "lumin") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 GilesStrong/lumin
#   1%|█                                                                               | 19/1440 [00:10<10:45,  2.20it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "worldsensing", name: "xyz-iot-monitoring") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 worldsensing/xyz-iot-monitoring
#   1%|█                                                                               | 20/1440 [00:10<10:52,  2.17it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "rcsb", name: "ciftools-java") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 rcsb/ciftools-java
#   1%|█▏                                                                              | 21/1440 [00:11<10:54,  2.17it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "cgre-aachen", name: "pynoddy") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 cgre-aachen/pynoddy
#   2%|█▏                                                                              | 22/1440 [00:11<10:54,  2.16it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "bashtage", name: "linearmodels") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 bashtage/linearmodels
#   2%|█▎                                                                              | 23/1440 [00:11<10:43,  2.20it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "pygae", name: "galgebra") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 pygae/galgebra
#   2%|█▎                                                                              | 24/1440 [00:12<10:20,  2.28it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "SandstoneHPC", name: "sandstone-ide") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 SandstoneHPC/sandstone-ide
#   2%|█▍                                                                              | 25/1440 [00:12<10:09,  2.32it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "darothen", name: "pyrcel") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 darothen/pyrcel
#   2%|█▍                                                                              | 26/1440 [00:13<10:00,  2.36it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "DD-DeCaF", name: "id-mapper") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 DD-DeCaF/id-mapper
#   2%|█▌                                                                              | 27/1440 [00:13<09:50,  2.39it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "Colectica", name: "curation") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 Colectica/curation
#   2%|█▌                                                                              | 28/1440 [00:14<09:56,  2.37it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "harnesscloud", name: "harness-resource-manager") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 harnesscloud/harness-resource-manager
#   2%|█▌                                                                              | 29/1440 [00:14<09:55,  2.37it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "huggingface", name: "transformers") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 huggingface/transformers
#   2%|█▋                                                                              | 30/1440 [00:14<09:57,  2.36it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "stadelmanma", name: "netl-ap-map-flow") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 stadelmanma/netl-ap-map-flow
#   2%|█▋                                                                              | 31/1440 [00:15<09:59,  2.35it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "jl-wynen", name: "isle") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 jl-wynen/isle
#   2%|█▊                                                                              | 32/1440 [00:15<11:03,  2.12it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "rodighiero", name: "DH2020") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 rodighiero/DH2020
#   2%|█▊                                                                              | 33/1440 [00:16<10:54,  2.15it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "scalaris-team", name: "scalaris") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 scalaris-team/scalaris
#   2%|█▉                                                                              | 34/1440 [00:16<11:35,  2.02it/s]
# Query failed to run by returning code of 401.
#             {
#               repository(owner: "FEEprojects", name: "plantower") {
#                 description
#                 dependencyGraphManifests(first: 50) {
#                   nodes {
#                     blobPath
#                     dependencies {
#                       nodes {
#                         packageName
#                         repository {
#                           name
#                           owner {
#                             login
#                           }
#                           primaryLanguage {
#                             name
#                           }
#                         }
#                         requirements
#                         hasDependencies
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#
# 500 FEEprojects/plantower
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2dc4f4115c62> in <module>
#      11
#      12 if __name__ == "__main__":
# ---> 13     unittest.main(argv=['first-arg-is-ignored'], exit=False)
#
# E:\Anaconda\lib\unittest\main.py in __init__(self, module, defaultTest, argv, testRunner, testLoader, exit, verbosity, failfast, catchbreak, buffer, warnings, tb_locals)
#      99         self.progName = os.path.basename(argv[0])
#     100         self.parseArgs(argv)
# --> 101         self.runTests()
#     102
#     103     def usageExit(self, msg=None):
#
# E:\Anaconda\lib\unittest\main.py in runTests(self)
#     269             # it is assumed to be a TestRunner instance
#     270             testRunner = self.testRunner
# --> 271         self.result = testRunner.run(self.test)
#     272         if self.exit:
#     273             sys.exit(not self.result.wasSuccessful())
#
# E:\Anaconda\lib\unittest\runner.py in run(self, test)
#     174                 startTestRun()
#     175             try:
# --> 176                 test(result)
#     177             finally:
#     178                 stopTestRun = getattr(result, 'stopTestRun', None)
#
# E:\Anaconda\lib\unittest\suite.py in __call__(self, *args, **kwds)
#      82
#      83     def __call__(self, *args, **kwds):
# ---> 84         return self.run(*args, **kwds)
#      85
#      86     def debug(self):
#
# E:\Anaconda\lib\unittest\suite.py in run(self, result, debug)
#     120
#     121             if not debug:
# --> 122                 test(result)
#     123             else:
#     124                 test.debug()
#
# E:\Anaconda\lib\unittest\suite.py in __call__(self, *args, **kwds)
#      82
#      83     def __call__(self, *args, **kwds):
# ---> 84         return self.run(*args, **kwds)
#      85
#      86     def debug(self):
#
# E:\Anaconda\lib\unittest\suite.py in run(self, result, debug)
#     120
#     121             if not debug:
# --> 122                 test(result)
#     123             else:
#     124                 test.debug()
#
# E:\Anaconda\lib\unittest\case.py in __call__(self, *args, **kwds)
#     734
#     735     def __call__(self, *args, **kwds):
# --> 736         return self.run(*args, **kwds)
#     737
#     738     def debug(self):
#
# E:\Anaconda\lib\unittest\case.py in run(self, result)
#     674                 outcome.expecting_failure = expecting_failure
#     675                 with outcome.testPartExecutor(self, isTest=True):
# --> 676                     self._callTestMethod(testMethod)
#     677                 outcome.expecting_failure = False
#     678                 with outcome.testPartExecutor(self):
#
# E:\Anaconda\lib\unittest\case.py in _callTestMethod(self, method)
#     631
#     632     def _callTestMethod(self, method):
# --> 633         method()
#     634
#     635     def _callTearDown(self):
#
# <ipython-input-3-2dc4f4115c62> in test_extractor(self)
#       8         git_hub_key = 'github_token'
#       9         hop = 1
# ---> 10         extractor_depend.getDependencies(input_file, output_file, git_hub_key, hop)
#      11
#      12 if __name__ == "__main__":
#
# ~\Downloads\SMA-master\test\extractor_depend.py in getDependencies(input_file, output_file, git_hub_key, hop)
#      22         link = link.rstrip()
#      23         owner, repo = link.split(".com/")[1].split("/")
# ---> 24         result = [dep['packageName'] for dep in gh.get_dependencies(repo_owner = owner, repo_name = repo, depth = hop)]
#      25         if(len(result) > 0):
#      26             dependency_data[link] = result
#
# ~\Downloads\SMA-master\test\extractor_depend.py in <listcomp>(.0)
#      22         link = link.rstrip()
#      23         owner, repo = link.split(".com/")[1].split("/")
# ---> 24         result = [dep['packageName'] for dep in gh.get_dependencies(repo_owner = owner, repo_name = repo, depth = hop)]
#      25         if(len(result) > 0):
#      26             dependency_data[link] = result
#
# ~\Downloads\SMA-master\xkcd2347\xkcd2347.py in get_dependencies(self, repo_owner, repo_name, depth, lang)
#     111             return
#     112
# --> 113         results = self.query(q % (repo_owner, repo_name))
#     114         if 'errors' in results and len(results['errors']) > 0:
#     115             print("error " + repo_owner +"/"+ repo_name)
#
# ~\Downloads\SMA-master\xkcd2347\xkcd2347.py in query(self, q)
#     162                 "Accept": "application/vnd.github.hawkgirl-preview+json"
#     163             }
# --> 164             resp = requests.post('https://api.github.com/graphql', json={'query': q}, headers=headers)
#     165             if resp.status_code == 200:
#     166                 data = resp.json()
#
# E:\Anaconda\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# E:\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# E:\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# E:\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# E:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# E:\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# E:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379         # Trigger any extra validation we need to do.
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#     383             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# E:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     974         # Force connect early to allow us to validate the connection.
#     975         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 976             conn.connect()
#     977
#     978         if not conn.is_verified:
#
# E:\Anaconda\lib\site-packages\urllib3\connection.py in connect(self)
#     306     def connect(self):
#     307         # Add certificate verification
# --> 308         conn = self._new_conn()
#     309         hostname = self.host
#     310
#
# E:\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     157
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# E:\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      59     family = allowed_gai_family()
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#      63         sock = None
#
# E:\Anaconda\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     916     # and socket type values to enum constants.
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#     920         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:
